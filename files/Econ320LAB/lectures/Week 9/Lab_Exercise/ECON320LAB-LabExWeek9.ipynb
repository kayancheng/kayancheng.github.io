# %% [markdown]
# # ECON 320 Lab Exercise : Week 9 — Reflecting on t-tests and p-values
#
# - Name : [Your Name]
#
# - Lab Section: [Your Lab Section Here]
#
# - Code for week 9's attendance: [Attendance code here]
#
# #### **Please submit the exercise on <u> *Canvas* </u> in form of a <u> *HTML/PDF* </u> file.**

# %% [markdown]
# ---
#
# #### 📝 Reflection (2–3 sentences)
# Revisit **Lecture 9**.
# In **2–3 sentences**, reflect on what you learned about *p-values* and *t-tests*:
#
# 1. Explain the **two‑sided $p$‑value** in the context of $H_0:\beta_1=0$.
# 2. Explain why a **small $p$** does **not** imply a **large effect**.

# %% [markdown]
# #### Put your answer here:

# %% [markdown]
# ---
# **End of Lab Exercise.**
