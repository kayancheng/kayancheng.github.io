# %% [markdown]
# # ECON 320 Lab Exercise : Week 10 — Reflecting on heteroskedasticity
#
# - Name : [Your Name]
#
# - Lab Section: [Your Lab Section Here]
#
# - Code for week 10's attendance: [Attendance code here]

# %% [markdown]
# #### **Please submit the exercise on <u> *Canvas* </u> in form of a <u> *HTML/PDF* </u> file.**

# %% [markdown]
# ---
#
# #### 📝 Reflection (2–3 sentences)
# Revisit **Lecture 10: Heteroskedasticity** and write a short reflection **(2–3 sentences)** in your own words on your main takeaways. You can mention (optional): what heteroskedasticity looks like (e.g., funnel plot), why analysts often default to **HC0** in cross-section, and how you would report results clearly.

# %% [markdown]
# #### Put your answer here:

# %% [markdown]
# ---
# **End of Lab Exercise.**
