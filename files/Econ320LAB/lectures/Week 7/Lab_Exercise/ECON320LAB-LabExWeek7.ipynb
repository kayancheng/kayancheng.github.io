# %% [markdown]
# # ECON 320 Lab Exercise : Week 7 — Reflecting on Omitted Variable Bias (OVB) 🎯
#
# - Name : [Your Name]
#
# - Lab Section: [Your Lab Section Here]
#
# - Code for week 7's attendance: [Attendance code here]
#
# #### **Please submit the exercise on <u> *Canvas* </u> in form of a <u> *HTML/PDF* </u> file.**

# %% [markdown]
# ---
#
# #### 📝 Reflection (2–3 sentences)
# Revisit **Lecture 7**.
# In **2–3 sentences**, reflect on what you learned about **omitted variable bias (OVB)** and **model specification**:
#
# - What was your main takeaway or “aha” moment?
# - How would you explain the trade-off between including too many vs. too few variables to someone new to regression?
#
# *(There are no right or wrong answers — this is to help you to consolidate your understanding.)*

# %% [markdown]
# #### Put your answer here:

# %% [markdown]
# ---
# **End of Lab Exercise.**
