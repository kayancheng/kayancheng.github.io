# %% [markdown]
# # ECON 320 Lab Exercise : Week 4 --- Forming your final project group!
#
# - **Name** : *[Your Name]*
# - **Lab Section**: *[Your Lab Section]*
# - **Attendance Code (Week 4)**: *[Enter code]*
#
# #### **Submit this notebook as an HTML/PDF on Canvas.**
#
# ---
#
# ### Forming your final project groups 👥
#
# This week we are **taking a break from the lab exercise** to give you time to form your final project groups.
#
# 📋 Please submit your group member list under:
# **Assignment → Final Project → Group Members** on Canvas.
#
# - ✅ Submit by **September 28**
# - 👥 Each group should have **4–5 members**
# - 🙋 Only **one person per group** needs to submit
# - ℹ️ If you’re not in a group by September 28, no worries — let me know and I can help connect you with classmates.

# %% [markdown]
# ---
# **End of Lab Exercise.**
