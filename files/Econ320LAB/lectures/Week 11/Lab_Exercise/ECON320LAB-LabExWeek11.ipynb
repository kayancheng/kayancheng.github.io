# %% [markdown]
# # ECON 320 Lab Exercise : Week 11 — Watch & Reflect 🎥 (Instrumental Variables)
#
# - Name : [Your Name]
#
# - Lab Section: [Your Lab Section Here]
#
# - Code for week 11's attendance: [Attendance code here]

# %% [markdown]
# #### **Please submit the exercise on <u> *Canvas* </u> in form of a <u> *HTML/PDF* </u> file.**

# %% [markdown]
# ---
# ### Instructions
#
# 1. Watch the video: [Introduction to Instrumental Variables (IV)](https://www.youtube.com/watch?v=eoJUPd6104Q) by [Marginal Revolution University](https://www.youtube.com/@MarginalRevolutionUniversity).
#
# 2. Reflect on the content and write a brief takeaway in the space provided below.
#
# ---
#
# #### 📝 Reflection (2–3 sentences)
#  Write your 1–2 sentence takeaway from the video.

# %% [markdown]
# #### Put your answer here:

# %% [markdown]
# ---
# **End of Lab Exercise.**
