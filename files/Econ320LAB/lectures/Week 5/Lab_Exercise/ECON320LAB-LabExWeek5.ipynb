# %% [markdown]
# # ECON 320 Lab Exercise : Week 5 — Group Communication Check-In
#
# - **Name** : *[Your Name]*
# - **Lab Section**: *[Your Lab Section]*
# - **Attendance Code (Week 5)**: *[Enter code]*
#
# ---
#
# This week we are **continuing our break from the lab exercise** to give you extra time to coordinate with your **final project group**.
#
# ### ✅ Action items for this week
#
# - **Check your group**: You can now view group lists on **Canvas → People → Groups**.
#
# - **Group check-in**: make sure everyone responds, share when you’re free, and schedule a short meeting **before next class**.
#
# - **Prepare for the meeting**:
#
#   - **Discuss** availability and set the meeting time.
#
#   - **Review** project guidelines and **brainstorm** potential topics.
#
# > ⚠️ If there is any inactive member in your group, please let me know as soon as possible so I can help you.
#
# <hr style="border: 1px dotted #bbb;">
#
# ### 📅 Reminder: Project Proposal Deadline
#
# - **Project proposal is due: Wednesday, October 15.**

# %% [markdown]
# ---
# **End of Lab Exercise.**

# %%
# Export to html helper
# !pip install nbconvert
# !jupyter nbconvert --to html --no-input --output="output_file_name.html" "ECON320LAB-LabExWeek5.ipynb"
# Out:
# ...
# [NbConvertApp] Converting notebook ECON320LAB-LabExWeek5.ipynb.ipynb to html
# [NbConvertApp] Writing 271889 bytes to output_file_name.html
